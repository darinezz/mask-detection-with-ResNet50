# %%
# 📌 Step 1: Install and Setup Kaggle API
# !pip install kaggle --upgrade --quiet

import os
import shutil
import zipfile

# 📌 Step 2: Create Kaggle API Directory & Move JSON
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

print("✅ Kaggle API key configured successfully.")

# 📌 Step 3: Download the Face Mask Dataset from Kaggle
# !kaggle datasets download -d omkargurav/face-mask-dataset --unzip -p /content/data

print("✅ Dataset successfully downloaded and extracted!")

# 📌 Step 4: Verify dataset structure
# Check the /content/data folder to determine the extracted folder name
data_folder = "/content/data"
print("📂 Contents of /content/data:", os.listdir(data_folder))

# For example, if the dataset extracts into a folder named "Face Mask Dataset",
# set the path accordingly:
dataset_path = "/content/data/data/with_mask"  # Adjust if necessary

if os.path.exists(dataset_path):
    print(f"✅ Dataset is available at: {dataset_path}")

else:
    raise FileNotFoundError(f"❌ Expected dataset directory '{dataset_path}' not found!")
# Out:
# cp: cannot stat '/content/kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# ✅ Kaggle API key configured successfully.
# Dataset URL: https://www.kaggle.com/datasets/omkargurav/face-mask-dataset
# License(s): unknown
# ...
#  97% 158M/163M [00:01<00:00, 115MB/s]
# 100% 163M/163M [00:01<00:00, 111MB/s]
# ✅ Dataset successfully downloaded and extracted!
# 📂 Contents of /content/data: ['data']
# ✅ Dataset is available at: /content/data/data/with_mask

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import os

# Set the dataset directory (update this path if necessary)
data_dir = "/content/data/data"

# Set image dimensions and training parameters
IMG_HEIGHT, IMG_WIDTH = 224, 224
BATCH_SIZE = 32
EPOCHS = 10

# Create an ImageDataGenerator with augmentation and a 20% validation split
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
)

# Create training data generator
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training",
    shuffle=True
)

# Create validation data generator
val_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation",
    shuffle=False
)

# Load the pre-trained ResNet50 model (exclude the top layers)
base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Add custom classification layers on top of ResNet50
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation="relu")(x)
x = Dropout(0.5)(x)
predictions = Dense(1, activation="sigmoid")(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=predictions)
model.summary()

# Compile the model using the Adam optimizer and binary crossentropy loss
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Train the model for 10 epochs
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

# Evaluate the model on the validation set
val_loss, val_acc = model.evaluate(val_generator)
print("Validation Loss: {:.4f}".format(val_loss))
print("Validation Accuracy: {:.4f}".format(val_acc))

# Plot training and validation accuracy and loss
acc = history.history['accuracy']
val_acc_hist = history.history['val_accuracy']
loss = history.history['loss']
val_loss_hist = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc_hist, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss_hist, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()
# Out:
# Found 6043 images belonging to 2 classes.
# Found 1510 images belonging to 2 classes.
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 230, 230, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 112, 112, 64)   │          9,472 │ conv1_pad[0][0]        │
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from PIL import Image
import requests
from io import BytesIO
import os

def download_image(url, save_path="sample_mask_image.jpg"):
    """
    Downloads an image from a URL and saves it to a specified path.
    Verifies that the file is a valid image.
    """
    try:
        response = requests.get(url, stream=True, timeout=10)
        response.raise_for_status()  # Raise HTTP errors if any

        # Open the image from the response
        img = Image.open(BytesIO(response.content))
        img.save(save_path)

        print(f"✅ Image successfully downloaded and saved as {save_path}")
        return save_path
    except Exception as e:
        print(f"❌ Error downloading image: {e}")
        return None

def preprocess_image(img_path, img_height=224, img_width=224):
    """
    Loads and preprocesses an image for prediction.
    """
    try:
        img = image.load_img(img_path, target_size=(img_height, img_width))
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array = preprocess_input(img_array)
        return img_array
    except Exception as e:
        print(f"❌ Error processing image: {e}")
        return None

def predict_mask(model, img_path, img_height=224, img_width=224):
    """
    Predicts whether a person is wearing a mask or not using a trained model.
    Returns the prediction label and confidence score.
    """
    img_array = preprocess_image(img_path, img_height, img_width)

    if img_array is None:
        return None, None  # Exit if image preprocessing fails

    prediction = model.predict(img_array)
    confidence = prediction[0][0]

    # Interpret results
    label = "without_mask" if confidence > 0.5 else "with_mask"
    confidence_percentage = round(confidence * 100, 2) if confidence > 0.5 else round((1 - confidence) * 100, 2)

    return label, confidence_percentage

def show_prediction(img_path, label, confidence):
    """
    Displays the image along with the prediction label and confidence score.
    """
    img = Image.open(img_path)

    plt.figure(figsize=(6,6))
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {label}\nConfidence: {confidence}%")
    plt.show()

# Example usage
image_url = "https://cdn.pfizer.com/pfizercom/styles/convert_to_webp/s3/African%2520businesswoman%2520with%2520face%2520mask%2520in%2520office.jpeg.webp?VersionId=8q7IcBLAfqi6koT6VjUmTrKXhHQtfW7.&itok=PJe51n3x"
image_path = download_image(image_url)

if image_path:
    prediction_label, prediction_confidence = predict_mask(model, image_path, 224, 224)

    if prediction_label:
        print(f"🟢 Prediction: {prediction_label} ({prediction_confidence}%)")
        show_prediction(image_path, prediction_label, prediction_confidence)
    else:
        print("❌ Prediction failed.")
# Out:
# ✅ Image successfully downloaded and saved as sample_mask_image.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 🟢 Prediction: with_mask (100.0%)
